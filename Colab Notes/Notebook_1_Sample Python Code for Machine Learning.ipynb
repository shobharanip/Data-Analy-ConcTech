# %% [markdown]
# #This Notebook shows the students on how the Python works in google colab

# %% [markdown]
# ##Sample Python Code for Machine Learning -- This is a text cell

# %%
#code cell
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Generate some sample data

# %%
np.random.seed(0)
X = np.linspace(0, 10, 100).reshape(-1, 1)
y = 2 * X + 1 + np.random.randn(100, 1)

# %% [markdown]
# # Create a Linear Regression instance

# %%
model = LinearRegression()

# %% [markdown]
# # Fit the model to the data

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Make predictions

# %%
y_pred = model.predict(X)

# %% [markdown]
# # Plot the results

# %%
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, y_pred, color='red', label='Linear regression')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()

# %% [markdown]
# # Print the model coefficients

# %%
print(f"Slope (coefficient): {model.coef_[0][0]:.2f}")
print(f"Intercept: {model.intercept_[0]:.2f}")
# Out:
# Slope (coefficient): 1.97
# Intercept: 1.21
