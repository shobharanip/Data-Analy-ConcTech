# %% [markdown]
# #How to load data from Google Drive into Google Colab (Note your data is in Google Drive). In real life data is loaded from SQL or through some level of API or URL Link

# %% [markdown]
# Step 1: Mount Google Drive

# %%
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Step 2: Access Files in Google Drive

# %%
import os

# List files in a specific directory in your Google Drive
directory = '/content/drive/My Drive'
files = os.listdir(directory)
print(files)
# Out:
# ['.ipynb_checkpoints', 'Monmouth_University', 'Archive']

# %%
# Read a file from Google Drive
#file_path = '/content/drive/My Drive/your_file.txt'  # Replace with your file's path

# %%
# Read a file from Google Drive
file_path = '/content/drive/My Drive/Monmouth_University/Fall_2024/Fall_24_DS_520_Intro_to_ML_Tuesday/Week_1_Python_Fundamentals/Code/olympics_dataset.csv'  # Replace with your file's path

# %%
with open(file_path, 'r') as file:
    content = file.read()
    print(content)

# %%
import pandas as pd

# %%
df = pd.read_csv(file_path)

# %%
# Display 3 random rows from the DataFrame
df.sample(3)
# Out:
#         player_id             Name Sex    Team  NOC  Year  Season    City  \
# 72573       87263     Brice Guyart   M  France  FRA  2000  Summer  Sydney
# 199267     242738  Kiichiro Toyama   M   Japan  JPN  1936  Summer  Berlin
# 231880       9328     Rim Nakamura   M   Japan  JPN  2020  Summer   Tokyo
#
#                         Sport                             Event     Medal
# 72573                 Fencing          Fencing Men's Foil, Team      Gold
# 199267             Gymnastics  Gymnastics Men's Team All-Around  No medal
# 231880  Cycling BMX Freestyle                        Men's Park  No medal
